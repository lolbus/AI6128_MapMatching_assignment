# %%
import pandas as pd
import numpy as np
import osmnx as ox
from shapely.geometry import Polygon
import ast
import matplotlib.pyplot as plt

# %%
edge_time_freq = pd.read_csv('./data/edge_time_freq.csv')
most_traversed = edge_time_freq.sort_values(by='traverse frequency', ascending=False)
longest_travel_time = edge_time_freq.sort_values(by='avg traverse time(s)', ascending=False)

# %%
import geopandas as gp
edge_dataframe = gp.GeoDataFrame.from_file( "porto_whole1/edges.shp")

# %%
def lighten_color(color, amount=0.5):
    """
    Lightens the given color by multiplying (1-luminosity) by the given amount.
    Input can be matplotlib color string, hex string, or RGB tuple.

    Examples:
    >> lighten_color('g', 0.3)
    >> lighten_color('#F034A3', 0.6)
    >> lighten_color((.3,.55,.1), 0.5)
    """
    import matplotlib.colors as mc
    import colorsys
    try:
        c = mc.cnames[color]
    except:
        c = color
    c = colorsys.rgb_to_hls(*mc.to_rgb(c))
    return colorsys.hls_to_rgb(c[0], 1 - amount * (1 - c[1]), c[2])

# %% [markdown]
# ### Plot No. 1 2 3 most traversedSegment

# %%
list_of_x = []
list_of_y = []
print(list_of_x)
#Extract top 5 sequence
for entry in most_traversed['points sequence'].iloc[0:3]:
    coords = np.array(ast.literal_eval(entry))
    list_of_x.append(coords[:, 0])
    list_of_y.append(coords[:, 1])
list_of_x = np.concatenate(list_of_x, axis=0)
list_of_y = np.concatenate(list_of_y, axis=0)

min_x = np.min(list_of_x) - 0.006
max_x = np.max(list_of_x) + 0.006
min_y = np.min(list_of_y)  - 0.002
max_y = np.max(list_of_y)  + 0.002
    
boundary = [min_x, max_x, min_y, max_y]
boundary_polygon = Polygon([(min_x,min_y),(max_x,min_y),(max_x,max_y),(min_x,max_y)])
G = ox.graph_from_polygon(boundary_polygon, network_type='drive')

fig, ax = ox.plot_graph(
    G,
    close=False,
    show=False,
    bgcolor="#333333",
    edge_color="w",
    edge_linewidth=0.3,
    node_size=0,
)
for i, entry in enumerate(most_traversed['points sequence'].iloc[0:3]):
    coords = np.array(ast.literal_eval(entry))
    list_of_x = coords[:, 0]
    list_of_y = coords[:, 1]
    #plt.scatter()
    
    import geopandas as gp
    edge_dataframe = gp.GeoDataFrame.from_file( "porto_whole1/edges.shp")
    stree_name = edge_dataframe.iloc[most_traversed.iloc[i]['edge index']]['name']
    stree_length = edge_dataframe.iloc[most_traversed.iloc[i]['edge index']]['length']
    stree_type = edge_dataframe.iloc[most_traversed.iloc[i]['edge index']]['highway']
    print("idx:"+ str(most_traversed.iloc[i]['edge index']) + " name:"+str(i+1)+":" +stree_name)
    print("edge location: ", (list_of_x[0], list_of_y[0]))
    tc = most_traversed.iloc[i]["traverse frequency"]
    print("traversed count: {0}. Road length {1}. Road type {2}".format(tc, stree_length, stree_type)) 
    print()

    plt.plot(list_of_x,list_of_y,linewidth=2, c=lighten_color('b', i*0.1))
    plt.plot(list_of_x[0],list_of_y[0],marker ="o", c=lighten_color('b', i*0.1))
    plt.plot(list_of_x[len(list_of_x)-1],list_of_y[len(list_of_y)-1],c=lighten_color('b', i*0.1), marker ="o")
plt.show()
# Out:
# []
# idx:2134 name:1:Rua do Doutor Roberto Frias
# edge location:  (-8.6001937, 41.1758894)
# traversed count: 80. Road length 160.35. Road type secondary
#
# idx:2760 name:2:Rua Doutor António Bernardino de Almeida
# edge location:  (-8.6051506, 41.1802304)
# traversed count: 80. Road length 212.545. Road type secondary
#
# idx:2802 name:3:Rua do Doutor Roberto Frias
# edge location:  (-8.5995986, 41.1772548)
# traversed count: 79. Road length 74.613. Road type secondary

# %% [markdown]
# ### Plot no 4 and no 5 most traversed segment

# %%
list_of_x = []
list_of_y = []
print(list_of_x)
#Extract top 5 sequence
for entry in most_traversed['points sequence'].iloc[3:5]:
    coords = np.array(ast.literal_eval(entry))
    list_of_x.append(coords[:, 0])
    list_of_y.append(coords[:, 1])
list_of_x = np.concatenate(list_of_x, axis=0)
list_of_y = np.concatenate(list_of_y, axis=0)

min_x = np.min(list_of_x) - 0.006
max_x = np.max(list_of_x) + 0.006
min_y = np.min(list_of_y)  - 0.002
max_y = np.max(list_of_y)  + 0.002
    
boundary = [min_x, max_x, min_y, max_y]
boundary_polygon = Polygon([(min_x,min_y),(max_x,min_y),(max_x,max_y),(min_x,max_y)])
G = ox.graph_from_polygon(boundary_polygon, network_type='drive')

fig, ax = ox.plot_graph(
    G,
    close=False,
    show=False,
    bgcolor="#333333",
    edge_color="w",
    edge_linewidth=0.3,
    node_size=0,
)
for i, entry in enumerate(most_traversed['points sequence'].iloc[3:5]):
    pointer = i + 3
    coords = np.array(ast.literal_eval(entry))
    list_of_x = coords[:, 0]
    list_of_y = coords[:, 1]
    #plt.scatter()
    
    import geopandas as gp
    edge_dataframe = gp.GeoDataFrame.from_file( "porto_whole1/edges.shp")
    stree_name = edge_dataframe.iloc[most_traversed.iloc[pointer]['edge index']]['name']
    stree_length = edge_dataframe.iloc[most_traversed.iloc[pointer]['edge index']]['length']
    stree_type = edge_dataframe.iloc[most_traversed.iloc[pointer]['edge index']]['highway']
    print("idx:"+ str(most_traversed.iloc[pointer]['edge index']) + " name:"+str(pointer+1)+":" +stree_name)
    print("edge location: ", (list_of_x[0], list_of_y[0]))
    tc = most_traversed.iloc[pointer]["traverse frequency"]
    print("traversed count: {0}. Road length {1}. Road type {2}".format(tc, stree_length, stree_type)) 
    print()

    plt.plot(list_of_x,list_of_y,linewidth=2, c=lighten_color('b', i*0.1))
    plt.plot(list_of_x[0],list_of_y[0],marker ="o", c=lighten_color('b', i*0.1))
    plt.plot(list_of_x[len(list_of_x)-1],list_of_y[len(list_of_y)-1],c=lighten_color('b', i*0.1), marker ="o")
plt.show()
# Out:
# []
# idx:6745 name:4:Rua do Clube dos Fenianos
# edge location:  (-8.6112234, 41.1494158)
# traversed count: 79. Road length 14.35. Road type secondary
#
# idx:1055 name:5:Avenida dos Aliados
# edge location:  (-8.6112107, 41.1492871)
# traversed count: 75. Road length 155.84900000000002. Road type secondary

# %% [markdown]
# ### Plot 1 2 Avg Traversed time

# %%
from matplotlib import cm
import matplotlib.colors as mcolors

list_of_x = []
list_of_y = []
top_edge_location =[]
print(list_of_x)
for entry in longest_travel_time['points sequence'].iloc[0:2]:
    coords = np.array(ast.literal_eval(entry))
    list_of_x.append(coords[:, 0])
    list_of_y.append(coords[:, 1])
list_of_x = np.concatenate(list_of_x, axis=0)
list_of_y = np.concatenate(list_of_y, axis=0)

min_x = np.min(list_of_x) - 0.005
max_x = np.max(list_of_x) + 0.005
min_y = np.min(list_of_y) - 0.005
max_y = np.max(list_of_y) + 0.005
    
boundary = [min_x, max_x, min_y, max_y]
boundary_polygon = Polygon([(min_x,min_y),(max_x,min_y),(max_x,max_y),(min_x,max_y)])
G = ox.graph_from_polygon(boundary_polygon, network_type='drive')

fig, ax = ox.plot_graph(
    G,
    #close=False,
    show=False,
    bgcolor="#333333",
    edge_color="w",
    edge_linewidth=0.3,
    node_size=0,
)

for i, entry in enumerate(longest_travel_time['points sequence'].iloc[0:2]):
    coords = np.array(ast.literal_eval(entry))
    list_of_x = coords[:, 0]
    list_of_y = coords[:, 1]
    #plt.scatter()
    
    import geopandas as gp
    edge_dataframe = gp.GeoDataFrame.from_file( "porto_whole1/edges.shp")
    stree_name = edge_dataframe.iloc[longest_travel_time.iloc[i]['edge index']]['name']
    stree_length = edge_dataframe.iloc[longest_travel_time.iloc[i]['edge index']]['length']
    stree_type = edge_dataframe.iloc[longest_travel_time.iloc[i]['edge index']]['highway']
    print("idx:"+ str(longest_travel_time.iloc[i]['edge index']) + " name:"+str(i+1)+":" +stree_name)
    print("edge location: ", (list_of_x[0], list_of_y[0]))
    agt = longest_travel_time.iloc[i]["avg traverse time(s)"]
    print("avg traverse time (approx seconds): {0}. Road length {1}. Road type {2}".format(agt, stree_length, stree_type)) 
    print()

    plt.plot(list_of_x,list_of_y,linewidth=2, c=lighten_color('r', i*0.15))
    plt.plot(list_of_x[0],list_of_y[0],marker ="o", c=lighten_color('r', i*0.15))
    plt.plot(list_of_x[len(list_of_x)-1],list_of_y[len(list_of_y)-1],c=lighten_color('r', i*0.1), marker ="o")
    
plt.show()
# Out:
# []
# idx:928 name:1:Rua do Sol
# edge location:  (-8.6054819, 41.1428869)
# avg traverse time (approx seconds): 1890.0. Road length 202.8. Road type residential
#
# idx:6982 name:2:['Avenida de Paiva Couceiro', 'Avenida de Gustavo Eiffel']
# edge location:  (-8.6097218, 41.1408406)
# avg traverse time (approx seconds): 637.5. Road length 2152.5350000000008. Road type primary

# %% [markdown]
# ### Plot No 3 Long traverse time road segment

# %%
from matplotlib import cm
import matplotlib.colors as mcolors

list_of_x = []
list_of_y = []
top_edge_location =[]
print(list_of_x)
for entry in longest_travel_time['points sequence'].iloc[2:3]:
    coords = np.array(ast.literal_eval(entry))
    list_of_x.append(coords[:, 0])
    list_of_y.append(coords[:, 1])
list_of_x = np.concatenate(list_of_x, axis=0)
list_of_y = np.concatenate(list_of_y, axis=0)

min_x = np.min(list_of_x) - 0.003
max_x = np.max(list_of_x) + 0.003
min_y = np.min(list_of_y) - 0.003
max_y = np.max(list_of_y) + 0.003
    
boundary = [min_x, max_x, min_y, max_y]
boundary_polygon = Polygon([(min_x,min_y),(max_x,min_y),(max_x,max_y),(min_x,max_y)])
G = ox.graph_from_polygon(boundary_polygon, network_type='drive')

fig, ax = ox.plot_graph(
    G,
    #close=False,
    show=False,
    bgcolor="#333333",
    edge_color="w",
    edge_linewidth=0.3,
    node_size=0,
)

for i, entry in enumerate(longest_travel_time['points sequence'].iloc[2:3]):
    pointer = i + 2
    coords = np.array(ast.literal_eval(entry))
    list_of_x = coords[:, 0]
    list_of_y = coords[:, 1]
    #plt.scatter()
    
    import geopandas as gp
    edge_dataframe = gp.GeoDataFrame.from_file( "porto_whole1/edges.shp")
    stree_name = edge_dataframe.iloc[longest_travel_time.iloc[pointer]['edge index']]['name']
    stree_length = edge_dataframe.iloc[longest_travel_time.iloc[pointer]['edge index']]['length']
    stree_type = edge_dataframe.iloc[longest_travel_time.iloc[pointer]['edge index']]['highway']
    print("idx:"+ str(longest_travel_time.iloc[pointer]['edge index']) + " name:"+str(pointer+1)+":" +stree_name)
    print("edge location: ", (list_of_x[0], list_of_y[0]))
    agt = longest_travel_time.iloc[pointer]["avg traverse time(s)"]
    print("avg traverse time (approx seconds): {0}. Road length {1}. Road type {2}".format(agt, stree_length, stree_type)) 
    print()

    plt.plot(list_of_x,list_of_y,linewidth=2, c=lighten_color('r', i*0.15))
    plt.plot(list_of_x[0],list_of_y[0],marker ="o", c=lighten_color('r', i*0.15))
    plt.plot(list_of_x[len(list_of_x)-1],list_of_y[len(list_of_y)-1],c=lighten_color('r', i*0.1), marker ="o")
    
plt.show()
# Out:
# []
# idx:3460 name:3:Rua do Universo
# edge location:  (-8.6390306, 41.1504681)
# avg traverse time (approx seconds): 480.0. Road length 57.147999999999996. Road type residential

# %% [markdown]
# ### No 4 No 5 highest Avg Traverse Time road segment

# %%
from matplotlib import cm
import matplotlib.colors as mcolors

list_of_x = []
list_of_y = []
top_edge_location =[]
print(list_of_x)
for entry in longest_travel_time['points sequence'].iloc[3:5]:
    coords = np.array(ast.literal_eval(entry))
    list_of_x.append(coords[:, 0])
    list_of_y.append(coords[:, 1])
list_of_x = np.concatenate(list_of_x, axis=0)
list_of_y = np.concatenate(list_of_y, axis=0)

min_x = np.min(list_of_x) - 0.003
max_x = np.max(list_of_x) + 0.003
min_y = np.min(list_of_y) - 0.003
max_y = np.max(list_of_y) + 0.003
    
boundary = [min_x, max_x, min_y, max_y]
boundary_polygon = Polygon([(min_x,min_y),(max_x,min_y),(max_x,max_y),(min_x,max_y)])
G = ox.graph_from_polygon(boundary_polygon, network_type='drive')

fig, ax = ox.plot_graph(
    G,
    #close=False,
    show=False,
    bgcolor="#333333",
    edge_color="w",
    edge_linewidth=0.3,
    node_size=0,
)

for i, entry in enumerate(longest_travel_time['points sequence'].iloc[3:5]):
    pointer = i + 3
    coords = np.array(ast.literal_eval(entry))
    list_of_x = coords[:, 0]
    list_of_y = coords[:, 1]
    #plt.scatter()
    
    import geopandas as gp
    edge_dataframe = gp.GeoDataFrame.from_file( "porto_whole1/edges.shp")
    stree_name = edge_dataframe.iloc[longest_travel_time.iloc[pointer]['edge index']]['name']
    stree_length = edge_dataframe.iloc[longest_travel_time.iloc[pointer]['edge index']]['length']
    stree_type = edge_dataframe.iloc[longest_travel_time.iloc[pointer]['edge index']]['highway']
    print("idx:"+ str(longest_travel_time.iloc[pointer]['edge index']) + " name:"+str(pointer+1)+":" +stree_name)
    print("edge location: ", (list_of_x[0], list_of_y[0]))
    agt = longest_travel_time.iloc[pointer]["avg traverse time(s)"]
    print("avg traverse time (approx seconds): {0}. Road length {1}. Road type {2}".format(agt, stree_length, stree_type)) 
    print()

    plt.plot(list_of_x,list_of_y,linewidth=2, c=lighten_color('r', i*0.15))
    plt.plot(list_of_x[0],list_of_y[0],marker ="o", c=lighten_color('r', i*0.15))
    plt.plot(list_of_x[len(list_of_x)-1],list_of_y[len(list_of_y)-1],c=lighten_color('r', i*0.1), marker ="o")
    
plt.show()
# Out:
# []
# idx:9881 name:4:['Rua de Frederico Ozanam', 'Rua Direita de Francos', 'Rua Airosa']
# edge location:  (-8.6389597, 41.1660014)
# avg traverse time (approx seconds): 470.0. Road length 299.577. Road type tertiary
#
# idx:7093 name:5:Rua de Pedro Hispano
# edge location:  (-8.6322544, 41.1643775)
# avg traverse time (approx seconds): 420.0. Road length 102.232. Road type residential
